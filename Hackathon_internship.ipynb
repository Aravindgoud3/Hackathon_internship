# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\kalali aravindgoud\Desktop\Dataset\dataframe_.csv')

# %%
data
# Out:
#            input      output
# 0    -122.740667 -130.572085
# 1    -121.531419 -129.938929
# 2    -134.917019 -130.141832
# 3    -120.605951 -125.760932
# 4    -129.894781 -112.785214
# ...          ...         ...
# 1692   25.410184  -76.380902
# 1693   29.537304  -82.796934
# 1694   31.633331  -87.000000
# 1695   29.091458 -104.943052
# 1696   17.145296 -101.726894
#
# [1697 rows x 2 columns]

# %% [markdown]
# # EDA

# %%
data.shape
# Out:
# (1697, 2)

# %%
data.describe()
# Out:
#              input       output
# count  1696.000000  1696.000000
# mean      1.159933   -34.088017
# std      79.005970    65.771112
# min    -134.962839  -132.422167
# 25%     -63.386506   -80.026767
# 50%      10.195194   -50.470981
# 75%      70.264109   -11.000000
# max     134.605775   134.425495

# %%
data.corr()
# Out:
#            input    output
# input   1.000000  0.511776
# output  0.511776  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1697 entries, 0 to 1696
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   1696 non-null   float64
#  1   output  1696 non-null   float64
# dtypes: float64(2)
# memory usage: 26.6 KB

# %%
# There are having only two columns of data points 1697

# %%
data.isnull().sum()
# Out:
# input     1
# output    1
# dtype: int64

# %%
# Only two NaN values present

# %%
data[data['input'].isnull()]
# Out:
#       input  output
# 1439    NaN     NaN

# %%
data['input'].value_counts()
# Out:
# -125.366669    11
#  112.633331    10
# -131.366669     8
# -119.366669     8
#  80.633331      7
#                ..
#  70.453760      1
#  49.257757      1
#  113.419710     1
# -48.077505      1
# -53.677306      1
# Name: input, Length: 991, dtype: int64

# %%
data['output'].value_counts() #imbalanced data
# Out:
# -95.000000     32
# -78.000000     12
# -33.000000     12
# -75.000000     10
# -32.000000     10
#                ..
#  115.000000     1
# -0.510703       1
#  115.438049     1
# -48.473313      1
# -79.131137      1
# Name: output, Length: 969, dtype: int64

# %%
# Removing that one datapoint which contains NaN values in it

# %%
data['input'].value_counts()
# Out:
# -125.366669    11
#  112.633331    10
# -131.366669     8
# -119.366669     8
#  80.633331      7
#                ..
#  70.453760      1
#  49.257757      1
#  113.419710     1
# -48.077505      1
# -53.677306      1
# Name: input, Length: 991, dtype: int64

# %%
data['output'].value_counts()
# Out:
# -95.000000     32
# -78.000000     12
# -33.000000     12
# -75.000000     10
# -32.000000     10
#                ..
#  115.000000     1
# -0.510703       1
#  115.438049     1
# -48.473313      1
# -79.131137      1
# Name: output, Length: 969, dtype: int64

# %%
data[1439:1440]
# Out:
#       input  output
# 1439    NaN     NaN

# %%
data[1439:]
# Out:
#            input      output
# 1439         NaN         NaN
# 1440  103.078927   41.517955
# 1441  106.633331   61.000000
# 1442  122.015450   46.388359
# 1443  103.579923   60.102083
# ...          ...         ...
# 1692   25.410184  -76.380902
# 1693   29.537304  -82.796934
# 1694   31.633331  -87.000000
# 1695   29.091458 -104.943052
# 1696   17.145296 -101.726894
#
# [258 rows x 2 columns]

# %%
data.drop(index=1439,inplace=True)

# %%
data.reset_index(inplace=True,drop=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1696 entries, 0 to 1695
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   1696 non-null   float64
#  1   output  1696 non-null   float64
# dtypes: float64(2)
# memory usage: 26.6 KB

# %%
data.duplicated().sum()
# Out:
# 606

# %%
# Having 606 duplicated datapoints, need to remove

# %%
data[data.duplicated()]
# Out:
#            input      output
# 106   -63.366669  -33.000000
# 464   112.633331  103.000000
# 715   -31.366669  -49.000000
# 819  -117.366669  -75.000000
# 865  -131.366669 -125.000000
# ...          ...         ...
# 1691   25.410184  -76.380902
# 1692   29.537304  -82.796934
# 1693   31.633331  -87.000000
# 1694   29.091458 -104.943052
# 1695   17.145296 -101.726894
#
# [606 rows x 2 columns]

# %%
data.drop_duplicates(inplace=True)

# %%
data[100:108]
# Out:
#          input     output
# 100 -58.988196 -42.242901
# 101 -85.808609 -28.620218
# 102 -63.366669 -33.000000
# 103 -72.707971 -39.590923
# 104 -63.386506 -20.975137
# 105 -48.536684 -29.370224
# 107 -76.555241 -23.929979
# 108 -59.690608 -43.663780

# %%
data.reset_index(inplace=True,drop=True)

# %%
import seaborn as sns

# %%
sns.boxplot(data['input'])
# Out:
# C:\Users\kalali aravindgoud\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='input'>

# %%
# There are no outliers in the dataset

# %%
data['input'].value_counts()
# Out:
#  112.633331    7
#  80.633331     5
# -15.366669     4
# -119.366669    4
#  47.633331     3
#               ..
#  46.999198     1
#  24.429056     1
# -117.366669    1
#  10.699264     1
# -103.293097    1
# Name: input, Length: 991, dtype: int64

# %%
# Need to StandardScaler

# %%
fv=data[['input']]
cl=data['output']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(fv,cl,test_size=0.1,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
std_xtrain=std.fit_transform(x_train)
std_xtest=std.transform(x_test)

# %%
std_xtrain
# Out:
# array([[ 0.81654241],
#        [-1.79511985],
#        [ 0.53377791],
#        [-1.32820676],
#        [ 1.5326564 ],
#        [ 0.73985559],
#        [ 0.97147658],
#        [ 0.23062542],
#        [-0.04819365],
#        [ 0.19200676],
#        [-0.06723947],
#        [ 0.2060468 ],
#        [-0.0608576 ],
#        [-0.11169654],
#        [-1.57907657],
#        [ 0.42614758],
#        [-1.4827446 ],
#        [ 1.45645728],
#        [-1.3233368 ],
#        [ 0.67008758],
#        [ 1.33776092],
#        [ 0.14392735],
#        [ 1.09572813],
#        [ 0.6142462 ],
#        [-1.14636563],
#        [ 0.86411828],
#        [-0.28347419],
#        [ 0.75756038],
#        [ 1.49735066],
#        [-0.53690327],
#        [ 0.18062733],
#        [-1.58911095],
#        [ 0.024208  ],
#        [-0.64550533],
#        [-1.43293699],
#        [-1.49298594],
#        [ 0.48904859],
#        [ 0.2060468 ],
#        [ 0.67630693],
#        [-0.01510726],
#        [ 0.0916592 ],
# ...

# %%
model=LinearRegression()
model.fit(std_xtrain,y_train)
# Out:
# LinearRegression()

# %%
cl
# Out:
# 0      -130.572085
# 1      -129.938929
# 2      -130.141832
# 3      -125.760932
# 4      -112.785214
#            ...
# 1085    121.096397
# 1086    123.609122
# 1087    127.197394
# 1088    128.170885
# 1089    123.087950
# Name: output, Length: 1090, dtype: float64

# %%
# y=wx+wo

# %%
model.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
# y=wx+wo

# %%
model.intercept_  # y intercept
# Out:
# -28.126312605751274

# %%
model.coef_ #slope
# Out:
# array([33.85053435])

# %%
predi=model.predict(std_xtest)
predi
# Out:
# array([  0.79027595, -34.47893913, -79.29203998,  -3.50733411,
#         14.78993254, -66.8019112 , -83.96528291, -42.56158772,
#          3.37166352,  -0.32471748, -38.64354448,  -1.79111163,
#        -15.55851206,  12.40652005, -84.09048352, -35.77938143,
#        -66.49947071,  -2.79227579,  25.9451163 , -54.04659725,
#         -2.92665678, -31.72667458, -18.17297479,  23.76601918,
#         17.21368597, -11.39264457, -35.83895269, -66.65627773,
#          1.66157581,  11.56748722, -40.47858131, -40.73949488,
#         10.685595  , -78.10398319, -12.03937184, -19.41998109,
#        -83.10482038,   5.75949076,  -2.05090232,  -4.53621608,
#          5.79845937, -15.52159436, -40.2710459 , -87.06249849,
#         26.53094772, -81.09863591, -82.06315903, -74.17658607,
#         17.12001279, -73.63973259, -25.88817188,  -4.10725951,
#          1.14246802,  19.9643541 ,  25.9117819 ,   1.59105526,
#        -82.67458912, -41.86164198, -73.20950133,   4.17054924,
# ...

# %%
pd.DataFrame({'Actual':y_test,'Predicted':predi})
# Out:
#          Actual  Predicted
# 545  -21.000000   0.790276
# 224  -74.487134 -34.478939
# 813  -61.347809 -79.292040
# 295   -5.494825  -3.507334
# 487  126.899744  14.789933
# ..          ...        ...
# 890  -88.520510 -29.758669
# 870 -114.455671 -23.021244
# 103  -39.590923 -62.600559
# 431   48.000000  10.685595
# 781  -36.638417 -67.025007
#
# [109 rows x 2 columns]

# %%
import seaborn as sns
sns.histplot(y_test,color='blue',alpha=0.5,bins=5)
sns.histplot(predi,color='red',alpha=0.5,bins=5)
# Out:
# <AxesSubplot:xlabel='output', ylabel='Count'>

# %%
# Evalution metrics

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,predi)
# Out:
# 3956.6296745572754

# %%
mean_absolute_error(y_test,predi)
# Out:
# 48.128739964625034

# %%
r2_score(y_test,predi)
# Out:
# 0.2772602300062653

# %%
# Getting r2 score of 27%

# %%
# Need of Feature engineering

# %%
data['input']=data['input']**2
data
# Out:
#              input      output
# 0     15065.271434 -130.572085
# 1     14769.885901 -129.938929
# 2     18202.602016 -130.141832
# 3     14545.795441 -125.760932
# 4     16872.654053 -112.785214
# ...            ...         ...
# 1085  12548.143513  121.096397
# 1086  14389.019022  123.609122
# 1087  12087.277402  127.197394
# 1088  12435.677389  128.170885
# 1089  12175.847196  123.087950
#
# [1090 rows x 2 columns]

# %%
fv=data[['input']]
cl=data['output']
x_train,x_test,y_train,y_test=train_test_split(fv,cl,test_size=0.1,random_state=0)
std=StandardScaler()
std_xtrain=std.fit_transform(x_train)
std_xtest=std.transform(x_test)
model=LinearRegression()
model.fit(std_xtrain,y_train)
predi=model.predict(std_xtest)

# %%
pd.DataFrame({'Actual':y_test,'Predicted':predi})
# Out:
#          Actual  Predicted
# 545  -21.000000 -32.426996
# 224  -74.487134 -67.548576
# 813  -61.347809  11.270411
# 295   -5.494825 -41.285092
# 487  126.899744   5.239818
# ..          ...        ...
# 890  -88.520510 -67.808196
# 870 -114.455671 -65.523415
# 103  -39.590923 -34.233216
# 431   48.000000  -7.200140
# 781  -36.638417 -24.038400
#
# [109 rows x 2 columns]

# %%
print('mean_squared_error:',mean_squared_error(y_test,predi))
print('mean_absolute_error:',mean_absolute_error(y_test,predi))
print('r2_score:',r2_score(y_test,predi))
# Out:
# mean_squared_error: 3606.3867799985674
# mean_absolute_error: 45.89698224123602
# r2_score: 0.3412375263105055

# %%
# Increased to 34%

# %%
:)
